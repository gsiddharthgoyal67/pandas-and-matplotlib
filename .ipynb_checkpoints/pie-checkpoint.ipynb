# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=[4,55,65,77,47,98]
y=[23,76,85,56,89,67]
player=["virat","sachin","dhoni","kapil","rohit"]
runs=[67,123,77,175,144]
exp=[0,0,0,0,0]
#plt.xlabel('x-axis')
#plt.ylabel('y-axis')
#plt.plot(x,y)
#plt.grid(color='green')
#plt.bar(x,y,label="air")
plt.pie(runs,labels=player,explode=exp)
plt.legend()
plt.show()
